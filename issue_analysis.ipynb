# %%
import pandas as pd

df = pd.read_csv("../data/geocoded_data/merged_2021_2025.csv")

# Parse datetime columns
datetime_cols = ["Opened", "Closed Date 1", "Closed Date 2", "closed"]
for col in datetime_cols:
    if col in df.columns:
        df[col] = pd.to_datetime(df[col], errors="coerce")

# Ensure numeric types
df["resolution_time_hours"] = pd.to_numeric(df["resolution_time_hours"], errors="coerce")
df["lat"] = pd.to_numeric(df["lat"], errors="coerce")
df["lng"] = pd.to_numeric(df["lng"], errors="coerce")

# Standardize boolean columns
bool_cols = ["has_closure_time", "ok"]
for col in bool_cols:
    if col in df.columns:
        df[col] = df[col].astype(str).str.lower().map({"true": True, "false": False})
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_28848\1891512058.py:3: DtypeWarning: Columns (1,3,4,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/geocoded_data/merged_2021_2025.csv")

# %%
#Cleanup of descriptions:
print("Length of df before cleanup:",len(df))
df = df[df["Description"].notna()]
df = df[df["Description"].str.strip() != ""]
df = df.drop_duplicates(subset=["Description", "Address", "Opened"])
print("Length of df after cleanup:", len(df))
# Out:
# Length of df before cleanup: 443308
# Length of df after cleanup: 273825

# %%
#Fetch unique data for scalable workload

df["Description_norm"] = (
    df["Description"]
    .str.strip()
    .str.lower()
)

unique_desc_df = df[["Description_norm"]].drop_duplicates().reset_index(drop=True)

print("Original rows:", len(df))
print("Unique descriptions:", len(unique_desc_df))
# Out:
# Original rows: 273825
# Unique descriptions: 909

# %%
import re

def normalize(text):
    text = text.lower().strip()
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text)
    return text

unique_desc_df["clean_text"] = unique_desc_df["Description_norm"].apply(normalize)

# %%
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
#Categorize them!
#Method 1

tfidf = TfidfVectorizer(
    max_features=2000,
    ngram_range=(1,2),
    stop_words="english"
)

X_tfidf = tfidf.fit_transform(unique_desc_df["clean_text"])

k = 10
kmeans_tfidf = KMeans(n_clusters=k, random_state=42)
unique_desc_df["cluster_tfidf"] = kmeans_tfidf.fit_predict(X_tfidf)

sil_tfidf = silhouette_score(X_tfidf, unique_desc_df["cluster_tfidf"])
print("TF-IDF Silhouette:", sil_tfidf)
# Out:
# TF-IDF Silhouette: 0.017114081304171375

# %%
#Method 2

from sentence_transformers import SentenceTransformer


model = SentenceTransformer("all-MiniLM-L6-v2")
X_embed = model.encode(unique_desc_df["clean_text"].tolist(), show_progress_bar=True)
kmeans_embed = KMeans(n_clusters=k, random_state=42)
unique_desc_df["cluster_embed"] = kmeans_embed.fit_predict(X_embed)

sil_embed = silhouette_score(X_embed, unique_desc_df["cluster_embed"])
print("Embedding Silhouette:", sil_embed)
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 397.51it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Batches: 100%|██████████| 29/29 [00:02<00:00, 13.63it/s]
# c:\Users\shrey\anaconda3\envs\geo\lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# Embedding Silhouette: 0.04657798260450363

# %%
#Method 3
from sklearn.cluster import AgglomerativeClustering

agg = AgglomerativeClustering(n_clusters=k)
unique_desc_df["cluster_hier"] = agg.fit_predict(X_embed)

sil_hier = silhouette_score(X_embed, unique_desc_df["cluster_hier"])
print("Hierarchical Silhouette:", sil_hier)
# Out:
# Hierarchical Silhouette: 0.03747142106294632

# %%
desc_counts = df["Description"].value_counts()

print(desc_counts.head(20))
print("\nTop 50 descriptions cover:",
      desc_counts.head(50).sum() / len(df))
# Out:
# Description
# Bulk Collection Request                                                                    39070
# Missed Residential Garbage                                                                 12900
# Damaged Garbage Cart Replacement                                                           11949
# Missing Garbage Cart                                                                        8513
# Missed Yard Trimmings                                                                       7602
# Damaged Recycling Cart Replacement                                                          7282
# Missing Recycling Cart                                                                      6329
# Account Information For Active Water And Sewer Account                                      5707
# Business License Renewal-City of Atlanta                                                    5156
# Property Owner or Renter Request to Establish New Water and Sewer Bill Account Services     5022
# Code Enforcement - Junk, Trash, and Debris-PRIVATE PROPERTY ONLY                            4756
# Missed Recycling                                                                            4655
# Potholes                                                                                    4535
# Cart Pick Up                                                                                4523
# Report Possible Water Leak or Main Break                                                    4280
# Damaged Garbage Bin Replacement                                                             3860
# Customer Report of No Water                                                                 3585
# Account Holder Request To Close/Transfer Water And Sewer Account                            3566
# Report Of Leaking Or Broken Water Meter                                                     3109
# Information on How to Request an Account Adjustment                                         2899
# Name: count, dtype: int64
#
# Top 50 descriptions cover: 0.7497744910070301

# %%
categories = [
    "Waste Management",
    "Water & Sewer",
    "Road & Infrastructure",
    "Code Enforcement",
    "Licensing & Permits",
    "Administrative / Account Services",
    "Public Safety",
    "Other"
]

# %%
category_anchors = {
    "Waste Management": "garbage recycling bulk trash cart yard trimmings waste pickup",
    "Water & Sewer": "water sewer leak meter no water account bill adjustment",
    "Road & Infrastructure": "pothole street repair sidewalk road damage",
    "Code Enforcement": "junk debris violation private property complaint",
    "Licensing & Permits": "business license permit renewal application",
    "Administrative / Account Services": "account information transfer close billing inquiry",
    "Public Safety": "hazard dangerous emergency complaint",
}

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

model = SentenceTransformer("all-MiniLM-L6-v2")

# Embed unique descriptions
desc_embeddings = model.encode(
    unique_desc_df["Description_norm"].tolist(),
    show_progress_bar=True
)

# Embed anchor texts
anchor_embeddings = model.encode(list(category_anchors.values()))
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 344.44it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Batches: 100%|██████████| 29/29 [00:02<00:00, 13.54it/s]

# %%
similarity_matrix = cosine_similarity(desc_embeddings, anchor_embeddings)

# Get best matching category index
best_match_idx = np.argmax(similarity_matrix, axis=1)

# Map index back to category name
category_names = list(category_anchors.keys())
unique_desc_df["category"] = [category_names[i] for i in best_match_idx]

# %%
unique_desc_df.to_csv("../data/geocoded_data/categories_new.csv", index=False)

# %%
### Map it back to the original data
import pandas as pd

unique_desc_df = pd.read_csv("../data/geocoded_data/categories_new.csv")

# %%
unique_desc_df["category"].value_counts()
# Out:
# category
# Public Safety                        179
# Code Enforcement                     176
# Waste Management                     138
# Water & Sewer                        137
# Licensing & Permits                  124
# Road & Infrastructure                100
# Administrative / Account Services     55
# Name: count, dtype: int64

# %%
# Map back to full dataset

desc_to_cat = dict(
    zip(unique_desc_df["Description_norm"], unique_desc_df["category"])
)

df["category"] = df["Description_norm"].map(desc_to_cat)

# %%
df.columns
# Out:
# Index(['Opened', 'Description', 'Address', 'Zip Code', 'Closed Date 1',
#        'Closed Date 2', 'Status', 'Number', 'closed', 'resolution_time_hours',
#        'has_closure_time', 'zip_clean', 'zip_int', 'address_norm', 'lat',
#        'lng', 'ok', 'year', 'Short Description', 'Description_norm',
#        'category'],
#       dtype='object')

# %%
df["category"].value_counts()
# Out:
# category
# Waste Management                     127321
# Water & Sewer                         49926
# Code Enforcement                      43899
# Road & Infrastructure                 17397
# Public Safety                         13276
# Administrative / Account Services     11605
# Licensing & Permits                   10401
# Name: count, dtype: int64

# %%
for _, row in unique_desc_df.iterrows():
    print(f"{row['Description_norm']}  -->  {row['category']}")
# Out:
# information on how to request an account adjustment  -->  Administrative / Account Services
# information on how to dispute your water and sewer bill  -->  Water & Sewer
# street light bulb replacement or street light is out - missing  -->  Road & Infrastructure
# right of way maintenance visibility/overgrowth issue  -->  Road & Infrastructure
# property owner or renter request to establish new water and sewer bill account services  -->  Water & Sewer
# mail/fax request on water/sewer accounts  -->  Water & Sewer
# code enforcement - junk, trash, and debris-private property only  -->  Code Enforcement
# misapplied payments on a water and sewer account  -->  Water & Sewer
# deposit or adjustment refund request on a water and sewer account  -->  Water & Sewer
# code enforcement general information  -->  Code Enforcement
# missed residential recycling backyard service  -->  Waste Management
# customer reports a leaking or damaged fire hydrant  -->  Public Safety
# bulk collection request  -->  Waste Management
# solid waste education and enforcement team (sweet) investigation request  -->  Waste Management
# missing recycling bin  -->  Waste Management
# how much is my court fine and how do i pay?  -->  Code Enforcement
# minor street light repair - physical structure  -->  Road & Infrastructure
# potholes  -->  Road & Infrastructure
# missed residential garbage  -->  Code Enforcement
# right of way maintenance (row) litter removal  -->  Waste Management
# account information for active water and sewer account  -->  Water & Sewer
# concrete (sidewalk, curb, driveway apron) repair  -->  Road & Infrastructure
# code enforcement - vacant lot - overgrowth (exceeds 12 inches) or junk, trash, and debris  -->  Code Enforcement
# report a damaged or missing manhole lid or storm drain grate/cover  -->  Road & Infrastructure
# code enforcement - parking on grass/ non- all weather surface  -->  Code Enforcement
# report of leaking or broken water meter  -->  Water & Sewer
# markings for preferential lines  -->  Licensing & Permits
# code enforcement - overgrown grass  -->  Code Enforcement
# request to cancel a scheduled bulk collection  -->  Code Enforcement
# scooter and bike removal requests (shareable dockless mobility devices)  -->  Road & Infrastructure
# scheduled bulk inquiry  -->  Administrative / Account Services
# balance information for active water and sewer account  -->  Water & Sewer
# customer reporting a possible sewer spill  -->  Public Safety
# customer report a burst pipe turn off water - small meter  -->  Water & Sewer
# property  owner  -->  Code Enforcement
# customer reporting a possible sewer backup  -->  Water & Sewer
# sewer spill  -->  Water & Sewer
# report low water pressure  -->  Water & Sewer
# bulk  -->  Waste Management
# damaged garbage bin replacement  -->  Waste Management
# report possible water leak or main break  -->  Water & Sewer
# account holder request to close/transfer water and sewer account  -->  Administrative / Account Services
# solid waste service changes beginning february 15, 2021  -->  Waste Management
# payment information for active water and sewer account  -->  Water & Sewer
# overpayment on a water and sewer account  -->  Water & Sewer
# damaged recycling bin replacement  -->  Waste Management
# how do i contact the solicitors office for the city of atlanta?  -->  Public Safety
# property owner  -->  Code Enforcement
# request duplicate water and sewer bill  -->  Water & Sewer
# missed recycling  -->  Waste Management
# missing garbage bin  -->  Waste Management
# bill inquiry for active water and sewer account  -->  Water & Sewer
# new trash and recycling service  -->  Waste Management
# missing payment on a water and sewer account  -->  Water & Sewer
# account information  -->  Administrative / Account Services
# dead animal removal  -->  Waste Management
# when is my court date and time?  -->  Code Enforcement
# missed yard trimmings  -->  Waste Management
# missed recycle  -->  Waste Management
# customer reporting cave-in/sink hole in yard, street, and or sidewalk  -->  Road & Infrastructure
# entire street missed - solid waste collections  -->  Waste Management
# customer mailing address change for water and sewer account  -->  Water & Sewer
# missed yard trimming  -->  Waste Management
# customer reports street flooding or possible clogged basin  -->  Water & Sewer
# balance  -->  Administrative / Account Services
# sws temporary service change - extra recycle bins  -->  Waste Management
# balance information  -->  Administrative / Account Services
# payment arrangements for active water and sewer account  -->  Water & Sewer
# utility poles blocking sidewalk access  -->  Road & Infrastructure
# solid waste education and enforcement team (sweet) investigation request- improper waste disposal/ i  -->  Waste Management
# registering a new business in the city of atlanta  -->  Licensing & Permits
# bin pick up  -->  Waste Management
# customer report of no water  -->  Water & Sewer
# policing alternatives & diversion initiative pad - welfare  -->  Public Safety
# remove obstruction in the right of way (row)  -->  Road & Infrastructure
# incorrect / incomplete account establishment for request submitted via dwm's online portal or facsim  -->  Administrative / Account Services
# report foul sewer odor  -->  Water & Sewer
# information about water and sewer appeals hearings  -->  Water & Sewer
# online payment for excise tax  -->  Administrative / Account Services
# report an encampment  -->  Public Safety
# street light pole/wire down or damaged  -->  Road & Infrastructure
# code enforcement - junk vehicle violation  -->  Code Enforcement
# additional bins  -->  Waste Management
# property owner, renter, attorney, or lender request for pay-off information on a water/sewer account  -->  Water & Sewer
# how to set up your water and sewer account for online viewing and/or payment  -->  Water & Sewer
# residential street sweeping out of quadrant  -->  Road & Infrastructure
# missed residential trash backyard service  -->  Waste Management
# office of buildings - arborist division  -->  Road & Infrastructure
# solid waste charges and billing  -->  Waste Management
# customer name change for water and sewer account  -->  Water & Sewer
# warning signs on property  -->  Public Safety
# grease trap requirements and plan reviews  -->  Waste Management
# how to report an abandoned vehicle on your street  -->  Code Enforcement
# dropped call / case created in error  -->  Public Safety
# meter purchases  -->  Water & Sewer
# code enforcement inspection- private property flooding  -->  Code Enforcement
# policing alternatives & diversion initiative pad - basic needs  -->  Public Safety
# what is my solid waste collection day  -->  Waste Management
# code enforcement process for property maintenance complaints  -->  Code Enforcement
# customer requests a credit transfer between water and sewer accounts  -->  Water & Sewer
# code enforcement outside of the city of atlanta jurisdiction  -->  Code Enforcement
# tree removal permit- public property  -->  Code Enforcement
# information about payment assistance programs for water bills via care and conserve  -->  Water & Sewer
# sinkhole  -->  Road & Infrastructure
# tree removal - private property  -->  Code Enforcement
# policing alternatives & diversion initiative pad - disturbance  -->  Public Safety
# i failed to appear at court  -->  Public Safety
# report concerns about power lines  -->  Public Safety
# code enforcement inspection - open and vacant  -->  Code Enforcement
# lifecyle building center of greater atlanta  -->  Licensing & Permits
# atlanta police emergency and non-emergency contact information  -->  Public Safety
# non emergency sign repair, replacement, or installation  -->  Public Safety
# business license renewal-city of atlanta  -->  Licensing & Permits
# code enforcement - exterior structural damage  -->  Code Enforcement
# missed same day pickup  -->  Waste Management
# missed collections day of scheduled service  -->  Water & Sewer
# damaged traffic sign (other mutcd signs)/removal of signange in city's right of way  -->  Road & Infrastructure
# business failure to file multiple year renewal  -->  Licensing & Permits
# report a person experiencing homelessness  -->  Public Safety
# report a missing or damaged water meter lid - small meter  -->  Water & Sewer
# establishing new water and sewer account following bankruptcy  -->  Water & Sewer
# where can i pay my water bill?  -->  Water & Sewer
# service complaint - department of public works (dpw)  -->  Code Enforcement
# atlanta police jurisdiction  -->  Public Safety
# unpaved roads repair  -->  Road & Infrastructure
# owner of multiple unit or commercial property request to close water and sewer account  -->  Water & Sewer
# customer missing required documents to establish/disconnect water service submitted via dwm's online  -->  Water & Sewer
# trash or recycling bin not properly placed back at curb after collection  -->  Waste Management
# illegal dumping visibility issue  -->  Code Enforcement
# pad referral follow-up requested  -->  Administrative / Account Services
# department of finance- office of revenue  -->  Administrative / Account Services
# downed tree reporting  -->  Public Safety
# coa park maintenance and facility repair  -->  Waste Management
# install or replace a no dumping or littering sign  -->  Code Enforcement
# georgia 811- call before you dig  -->  Public Safety
# what is the pretrial intervention program?  -->  Public Safety
# plumbers invoice for dwm sewer issue inspection  -->  Water & Sewer
# customer report a burst pipe turn on water - small meter  -->  Water & Sewer
# change of business ownership for sole ownership and partnership  -->  Licensing & Permits
# payment arrangements for water and sewer accounts with balances greater than fifty thousand dollars  -->  Water & Sewer
# information about senior citizen discount program for water and sewer bill  -->  Water & Sewer
# purchased bin  -->  Waste Management
# information about payment assistance programs via social service agencies  -->  Administrative / Account Services
# dumpster violations-sweet inspection  -->  Code Enforcement
# pedestrian crosswalks and other pavement markings  -->  Road & Infrastructure
# code enforcement - interior/structural  -->  Code Enforcement
# late fee or penalty for a water and sewer account  -->  Water & Sewer
# general inquiry, balance, and payment information for active water and sewer account  -->  Water & Sewer
# code enforcement - mold and fungal growth  -->  Code Enforcement
# multi-family dumpster  collections  -->  Waste Management
# filing a police report online with the atlanta police department  -->  Public Safety
# 411 coa directory or csc queue transfer  -->  Administrative / Account Services
# who owns the creeks?  -->  Water & Sewer
# information about filling your swimming pool  -->  Water & Sewer
# report discolored or odorous water coming out of faucet  -->  Water & Sewer
# professional practitioners registration and renewals  -->  Licensing & Permits
# contact streets and sidewalks  -->  Road & Infrastructure
# damaged traffic sign (other mutcd signs)/removal of signage in city's right of way  -->  Road & Infrastructure
# grease management - information about fats, oils, and grease program  -->  Waste Management
# 411- directory assistance-outside entities  -->  Administrative / Account Services
# request copy of business tax certificate or a good standing letter  -->  Licensing & Permits
# code enforcement - graffiti complaints  -->  Code Enforcement
# restoration services due to sewer related repairs  -->  Road & Infrastructure
# information about the city of atlanta's toilet rebate program  -->  Waste Management
# report an unlicensed business operating in the city  -->  Licensing & Permits
# submit a claim for damages with city of atlanta  -->  Code Enforcement
# code enforcement - damaged accessory structure  -->  Code Enforcement
# private property matters not handled by the city of atlanta  -->  Code Enforcement
# traffic study  inspection  -->  Road & Infrastructure
# open records request for the city of atlanta department of watershed management  -->  Water & Sewer
# final/close business  -->  Administrative / Account Services
# file a building complaint  -->  Code Enforcement
# check property zoning  -->  Code Enforcement
# code enforcement - burnt structure  -->  Code Enforcement
# information regarding septic tanks and related billing  -->  Water & Sewer
# bees - beehives  -->  Waste Management
# restoration services due to water related repairs  -->  Water & Sewer
# damaged or missing street name sign in need of replacement or repair  -->  Road & Infrastructure
# request business tax refund equal to or less than five thousand dollars ($5,000) from city of atlant  -->  Administrative / Account Services
# report possible misuse of water services and meter or fire hydrant illegal consumptions  -->  Water & Sewer
# code enforcement inspection- open and vacant  -->  Code Enforcement
# colored pavement markings  -->  Road & Infrastructure
# request new or cancel backyard service  -->  Code Enforcement
# customer report a burst pipe turn on water - large meter  -->  Water & Sewer
# united way of greater atlanta 2-1-1  -->  Public Safety
# street pavement and curb markings including crosswalks  -->  Road & Infrastructure
# dumpster request for neighborhood clean up project  -->  Waste Management
# illegal signs in the city's right of way  -->  Code Enforcement
# customer request to locate water meter  -->  Water & Sewer
# water and sewer letter of availability request  -->  Water & Sewer
# 2021 alcohol renewal season  -->  Licensing & Permits
# municipal court of atlanta  -symptoms/exposure to covid-19  -->  Public Safety
# city of atlanta ownership of storm water pipes that cross private property  -->  Water & Sewer
# code enforcement - home boarded over 6 months  -->  Code Enforcement
# general information on homestead exemptions for fulton county  -->  Licensing & Permits
# code enforcement - unsanitary conditions  -->  Public Safety
# new street light installation or new street light study request  -->  Road & Infrastructure
# grass cutting out of quadrant  -->  Road & Infrastructure
# code enforcement - flaking and peeling paint  -->  Code Enforcement
# policing alternatives & diversion initiative pad - mental health  -->  Public Safety
# online password reset assistance to access your water and sewer account  -->  Water & Sewer
# contact garbage, recycling & graffiti  -->  Code Enforcement
# code enforcement lien pay off  -->  Code Enforcement
# graffiti complaints  -->  Code Enforcement
# customer unable to pay water & sewer account  -->  Water & Sewer
# schedule clean up in a city of atlanta neighborhood  -->  Waste Management
# soil erosion and sedimentation control  -->  Code Enforcement
# containers and receptacles left on streets by citizen  -->  Road & Infrastructure
# who is responsible for addressing creek flooding?  -->  Water & Sewer
# locate and mark  -->  Road & Infrastructure
# entrapment from a downed tree  -->  Public Safety
# how can i change over from a septic tank to city (public) sewer?  -->  Water & Sewer
# missing payment  -->  Administrative / Account Services
# atl permit navigator  -->  Licensing & Permits
# residential parking permits  -->  Licensing & Permits
# update business tax certificate  -->  Licensing & Permits
# property in flood plain  -->  Code Enforcement
# emergency traffic signal repair  -->  Public Safety
# code enforcement inspection- no heat  -->  Public Safety
# demolition permits  -->  Code Enforcement
# code enforcement inspection - exposed wiring  -->  Public Safety
# covid-19: transportation to mercedes benz stadium for vaccine appointment  -->  Public Safety
# center for hard to recycle materials (charm)  -->  Waste Management
# interpretation services for city of atlanta agencies/departments  -->  Public Safety
# contractor equipment blocking the row  -->  Code Enforcement
# emergency signs and pole repair replacement  -->  Public Safety
# asphalt point repair  -->  Road & Infrastructure
# open records request for the city of atlanta police department  -->  Administrative / Account Services
# how do i reschedule my initial court date? (only available if court date has not passed)  -->  Licensing & Permits
# speed humps  -->  Waste Management
# marta stop or city of atlanta community trash bin that needs to be serviced  -->  Waste Management
# code enforcement inspection - raw sewage  -->  Code Enforcement
# relocation of water meter request  -->  Water & Sewer
# office of buildings - express permits division  -->  Licensing & Permits
# code enforcment - dilapidated structures  -->  Code Enforcement
# gcal - georgia crisis and access line  -->  Public Safety
# possible crossed meter  -->  Water & Sewer
# traffic study  -->  Road & Infrastructure
# report loose metal plate- department of public works  -->  Code Enforcement
# minor street light repair-physical structure  -->  Road & Infrastructure
# repair or install specialty signs  -->  Road & Infrastructure
# security code request to access your water and sewer account  -->  Water & Sewer
# what is the process for picking up, changing and/or paying for a city of atlanta police report?  -->  Water & Sewer
# open records request for the department of public works  -->  Administrative / Account Services
# business tax rate calculation  -->  Licensing & Permits
# customer report a burst pipe turn off water - large meter  -->  Water & Sewer
# hydrant meter rental  -->  Water & Sewer
# scooter and bike removal  -->  Road & Infrastructure
# report a missing or damaged water meter lid - large meter  -->  Water & Sewer
# residential street sweeping in quadrant  -->  Road & Infrastructure
# parking enforcement request  -->  Code Enforcement
# junk vehicle parked on the street  -->  Code Enforcement
# customer reports valuables dropped or discovered in sewer drain located in the public right of way  -->  Water & Sewer
# limited home repair assistance  -->  Road & Infrastructure
# grass cutting in quad  -->  Waste Management
# code enforcement placard removal  -->  Code Enforcement
# office of zoning and development  -->  Licensing & Permits
# tree or shrub pruning  -->  Waste Management
# contact the city of atlanta office of constituent services  -->  Public Safety
# atlanta city council  -->  Public Safety
# missed trash backyard service  -->  Waste Management
# cost of permit for sewer tap  -->  Water & Sewer
# multi-family dumpster collections  -->  Waste Management
# building material, construction and demolition waste  -->  Waste Management
# office of buildings - commercial permits (construction)  -->  Licensing & Permits
# atlanta department of transportation (atldot) online permits system  -->  Licensing & Permits
# requirements for flow test and 24 hour test  -->  Water & Sewer
# service complaint - atlanta police department - code enforcement (apd)  -->  Public Safety
# stop a sinkhole from expanding  -->  Road & Infrastructure
# online payment for general business tax  -->  Licensing & Permits
# updates on 2021 submitted renewals  -->  Licensing & Permits
# missed recycling backyard service  -->  Waste Management
# contact housing, buildings & construction  -->  Code Enforcement
# fence permits  -->  Licensing & Permits
# code enforcement - dilapidated structures  -->  Code Enforcement
# replace/readjust loose street plate for department of watershed  -->  Water & Sewer
# 912 release request  -->  Public Safety
# atlcore - busines licensing and permitting portal - department of finance  -->  Licensing & Permits
# discoloration of creek  -->  Water & Sewer
# contaminated recycling bin  -->  Waste Management
# office of buildings - residential permits (construction)  -->  Licensing & Permits
# information and resources on the renew atlanta infrastructure bond program  -->  Licensing & Permits
# open records request for the department of customer service / atl311  -->  Administrative / Account Services
# noise complaints  -->  Code Enforcement
# streetlight locate request  -->  Road & Infrastructure
# board of zoning adjustment (bza) - overview, application submission, public hearings schedule  -->  Licensing & Permits
# emergency services - police  -->  Public Safety
# contact public safety  -->  Public Safety
# identification of tree being public or private  -->  Code Enforcement
# office of buildings - overview, location and office hours  -->  Licensing & Permits
# cares warm line - ga council on substance abuse non-emergency addiction recovery support line  -->  Public Safety
# office of buildings - electrical, hvac or plumbing permits  -->  Licensing & Permits
# dead animal  -->  Public Safety
# court disposition requests  -->  Administrative / Account Services
# i can't find my citation online  -->  Licensing & Permits
# atlcore - business licensing and permitting portal - department of finance  -->  Licensing & Permits
# customer requests a refund on a fire hydrant meter rental  -->  Water & Sewer
# commercial account inquiries - department of watershed management  -->  Water & Sewer
# water or sewer service line warranties  -->  Water & Sewer
# where can i get a t-22b, certification of inspection for vehicle identification number (vin) form?  -->  Licensing & Permits
# dispute request  -->  Code Enforcement
# verify existing and approved alcohol license in the city of atlanta  -->  Licensing & Permits
# how do i find my police precinct or zone information?  -->  Public Safety
# covid-19 vaccination  -->  Public Safety
# how do i contact my probation officer?  -->  Public Safety
# make an appointment to meet the mayor  -->  Public Safety
# playground inspections or repairs in coa parks  -->  Code Enforcement
# erosion complaint  -->  Code Enforcement
# city of atlanta expands construction and property code enforcement  -->  Code Enforcement
# repair or install warning signs and object markers  -->  Public Safety
# i was told that i need to register my alarm system. what do i need to do?  -->  Licensing & Permits
# backflow prevention for meter purchases (fire services, commercial and irrigation)  -->  Water & Sewer
# detention pond maintenance for standing water  -->  Water & Sewer
# city of atlanta parks and recreation  -->  Code Enforcement
# reconnect water and sewer services following payment or payment arrangements  -->  Water & Sewer
# contact us- atl311  -->  Public Safety
# new sewer installation tie-ins  -->  Water & Sewer
# high water pressure compliant  -->  Water & Sewer
# information on state and federal highway, road, and/or rail construction projects  -->  Road & Infrastructure
# how much is my court fine and how do i pay  -->  Code Enforcement
# recycling perks program  -->  Waste Management
# sws garbage truck fluid leaking on the street  -->  Road & Infrastructure
# real estate ownership in the city of atlanta  -->  Code Enforcement
# request business tax refund greater than five thousand dollars ($5,000) from city of atlanta  -->  Licensing & Permits
# in-rem process  -->  Licensing & Permits
# public space trash receptacles  -->  Waste Management
# natural creek flooding  -->  Water & Sewer
# reporting a water leak in coa park  -->  Water & Sewer
# youth entrepreneurship advisory council recommendations  -->  Licensing & Permits
# code enforcement inspection - private property flooding  -->  Code Enforcement
# when is my court date  -->  Code Enforcement
# tenant/landlord disputes  -->  Public Safety
# what are yard trimmings?  -->  Waste Management
# illegal dumping visbility issue  -->  Code Enforcement
# multifamily buildings recycling initiative  -->  Waste Management
# what is the court doing to protect the public?  -->  Code Enforcement
# non emergency traffic signal repair  -->  Public Safety
# how can i handle my ticket if i live out of town?  -->  Public Safety
# general service complaint  -->  Public Safety
# covid-19 - fulton county emergency rental assistance program  -->  Public Safety
# can an officer be dispatched to perform a safety/welfare check on someone i know in atlanta?  -->  Public Safety
# concrete (sidewalk, curb, driveway apron) inspection  -->  Road & Infrastructure
# customer reporting cave-in/sink hole in yard, street, and/or sidewalk  -->  Road & Infrastructure
# register gun(s)  -->  Licensing & Permits
# atlanta recycles day  -->  Waste Management
# right of way (row) permits  -->  Licensing & Permits
# rooming houses  -->  Code Enforcement
# covid-19 emergency rental & mortgage assistance program through united way  -->  Public Safety
# americans with disabilities act (ada) ramp installation  -->  Licensing & Permits
# information about water conservation  -->  Water & Sewer
# service complaint - department of watershed management (dwm)  -->  Water & Sewer
# request for additional patrolling  -->  Public Safety
# removal of graffiti in the right of way (row)  -->  Code Enforcement
# property survey or plat map  -->  Code Enforcement
# code enforcement- flaking and peeling paint  -->  Code Enforcement
# how do i hire an off-duty atlanta police officer for my event?  -->  Public Safety
# covid-19 vaccinations - united way transportation assistance  -->  Public Safety
# contact parks and trees  -->  Public Safety
# false alarms  -->  Public Safety
# neighborhood planning unit (npu)  -->  Waste Management
# who handles accident reports in the city of atlanta?  -->  Public Safety
# one atlanta: one apd immediate action plan  -->  Public Safety
# bridge repairs  -->  Road & Infrastructure
# meter abandonment  -->  Water & Sewer
# property line location  -->  Code Enforcement
# heritage owner-occupied rehab housing programs  -->  Waste Management
# notify atl- city of atlanta emergency alert system  -->  Public Safety
# service complaint - department of transportation (atldot)  -->  Public Safety
# clean water atlanta - consent decree program  -->  Water & Sewer
# information for senior citizens about atlanta fire rescue programs  -->  Public Safety
# how to request removal from the notifyatl database  -->  Code Enforcement
# how to report an inoperable elevator in the city of atlanta  -->  Public Safety
# office of buildings - inspections  -->  Public Safety
# pad outreach referral  -->  Public Safety
# information on invest atlanta  -->  Licensing & Permits
# adrc - aging & disability resource connection (empowerline)  -->  Administrative / Account Services
# assistance with rodent and/or insect control  -->  Waste Management
# pedestrian pathway request  -->  Road & Infrastructure
# solid waste services memorial day collection schedule  -->  Waste Management
# how do i report drug activity?  -->  Public Safety
# phone spoofing  -->  Public Safety
# mayor keisha lance bottoms extends administrative orders related to covid-19  -->  Public Safety
# information on fire hydrant installation and/or relocation  -->  Water & Sewer
# code enforcement inspection - no heat  -->  Public Safety
# requesting a new sidewalk  -->  Road & Infrastructure
# report stray/aggressive/vicious dogs or other animals  -->  Code Enforcement
# policing alternatives & diversion initiative pad - public indecency  -->  Public Safety
# what does the city consider garbage?  -->  Waste Management
# demolition process  -->  Waste Management
# code enforcement on commercial property  -->  Code Enforcement
# speed monitoring  -->  Code Enforcement
# information on how to qualify for participation in the diverted water program  -->  Water & Sewer
# if i believe that i am a victim of identity theft, what do i do?  -->  Administrative / Account Services
# install no illegal dumping sign  -->  Code Enforcement
# children at play signs requested  -->  Public Safety
# street light out  -->  Road & Infrastructure
# service complaint - department of finance  -->  Public Safety
# report bankruptcy to the city  -->  Code Enforcement
# planting trees in the right of way/public property  -->  Code Enforcement
# duplicate pad referral  -->  Administrative / Account Services
# green infrastructure  -->  Road & Infrastructure
# policing alternatives & diversion initiative pad - substance use  -->  Public Safety
# street number assignments  -->  Road & Infrastructure
# pothole  -->  Road & Infrastructure
# concrete/sidewalk small scheduled repairs  -->  Road & Infrastructure
# property survey does not match city's base map  -->  Code Enforcement
# business license number request  -->  Licensing & Permits
# payment for wholesale alcohol excise tax  -->  Licensing & Permits
# city of atlanta online alcohol license renewal  -->  Licensing & Permits
# business tax amendment  -->  Licensing & Permits
# e-911 public safety access assessment  -->  Public Safety
# application/renewal requirements for the city of atlanta private property food vending permit  -->  Licensing & Permits
# invest atlanta events  -->  Public Safety
# estreet missed yard trimmings  -->  Waste Management
# application requirements for the city of atlanta public right of way food truck vending permit  -->  Licensing & Permits
# non-profit license and business application  -->  Licensing & Permits
# missing recycling  -->  Waste Management
# large gathering in a park  -->  Code Enforcement
# missed residential garbage backyard  -->  Code Enforcement
# certificate of occupancy  -->  Licensing & Permits
# what is vegetative overgrowth?  -->  Waste Management
# insurance licensing for businesses operating in the city of atlanta  -->  Licensing & Permits
# request for handicap parking  -->  Code Enforcement
# estreet missed residential garbage  -->  Code Enforcement
# street light repairs  -->  Road & Infrastructure
# sight distance study  -->  Licensing & Permits
# ppa - customer unable to make payment  -->  Water & Sewer
# clean and close process  -->  Administrative / Account Services
# tips for mosquito control by the mayor's office of emergency preparedness  -->  Public Safety
# how do i report a vehicle stolen?  -->  Code Enforcement
# vacant property registration process  -->  Licensing & Permits
# solid waste services - july 4th holiday  -->  Waste Management
# request for solid waste fee reduction/tax exemption  -->  Waste Management
# how often are storm drains/catch basins cleaned?  -->  Water & Sewer
# contact the city of atlanta human resources department  -->  Public Safety
# utility permit  -->  Licensing & Permits
# contact emergency services  -->  Public Safety
# renewals not completed in 2020  -->  Licensing & Permits
# large hole in street  -->  Road & Infrastructure
# sidewalk feared to collapse  -->  Road & Infrastructure
# update officers for corporations  -->  Licensing & Permits
# pad referral follow-up request  -->  Administrative / Account Services
# pad participant contact requested  -->  Public Safety
# business occupation tax certificate renewal - city of atlanta  -->  Licensing & Permits
# recycling fee exemption  -->  Waste Management
# apd/georgia tech/marta officer pad referral  -->  Licensing & Permits
# policing alternatives & diversion initiative pad - public health  -->  Public Safety
# caution - children at play sign  -->  Public Safety
# fulton and dekalb county animal services  -->  Licensing & Permits
# covid-19: eviction assistance during  -->  Public Safety
# dwm rain barrel workshop  -->  Waste Management
# operation clean sweep  -->  Waste Management
# request rescheduling of a water and sewer appeal hearing  -->  Water & Sewer
# tax lien properties/tax lien sales  -->  Code Enforcement
# commercial dumpsters  -->  Waste Management
# updating business tax certificate if name/location changed in previous year  -->  Licensing & Permits
# diversion problem-solving strategy and housing solution referrals  -->  Public Safety
# nuisance abatement  -->  Code Enforcement
# stormwater infrastructure  -->  Water & Sewer
# repair transferred from dwm for atldot to complete  -->  Road & Infrastructure
# water testing resource site for home or business  -->  Water & Sewer
# city services for the city of south fulton loch lomond neighborhood  -->  Road & Infrastructure
# concrete (sidewalk, curb, driveway apron) inspections  -->  Road & Infrastructure
# what is watershed protection?  -->  Water & Sewer
# new/cancel trash and recycling service  -->  Waste Management
# who to speak to about filming in your neighborhood  -->  Code Enforcement
# how to file a complaint about prostitutes in your neighborhood  -->  Code Enforcement
# georgia department of public health  -->  Public Safety
# housing follow-up requested  -->  Code Enforcement
# blended mobile crisis response services (bmcrs)  -->  Public Safety
# request for solid waste fee reduction  -->  Waste Management
# how to void a code enforcement case created in error?  -->  Code Enforcement
# property tax and solid waste liens with fulton or dekalb county  -->  Code Enforcement
# what are my rights as a victim of a violent crime in the state of georgia?  -->  Code Enforcement
# how to report possible vending cart/kiosk violations  -->  Code Enforcement
# no erosion control on land disturbance site  -->  Code Enforcement
# worksource atlanta (formerly atlanta workforce development agency)  -->  Licensing & Permits
# location and service rules for approved private property food and mobile food unit vendors  -->  Licensing & Permits
# pedestrian plaza/boardwalk repairs  -->  Road & Infrastructure
# contact atlanta housing authority  -->  Public Safety
# tree inspection-arborist  -->  Waste Management
# parking meter enforcement hours  -->  Water & Sewer
# mail/fax request for dwm senior citizen discount form  -->  Administrative / Account Services
# entire street missed - garbage  -->  Road & Infrastructure
# entire street missed - yard trimming  -->  Waste Management
# new residential permit parking area  -->  Licensing & Permits
# entire street missed - recycling  -->  Waste Management
# entire street missed- all services (garbage, recycling and yard trimming)  -->  Waste Management
# contact utilities  -->  Public Safety
# house shakes when buses pass by  -->  Code Enforcement
# compliance resolution  -->  Public Safety
# file a complaint of misconduct or corruption against an employee of the atlanta police department  -->  Public Safety
# backflow prevention for hydrant meters  -->  Water & Sewer
# report loose metal plate  -->  Public Safety
# how to report a vehicle was broken into and items were stolen  -->  Code Enforcement
# payment for excise tax  -->  Water & Sewer
# missed recycle collection  -->  Waste Management
# police precinct or zone information  -->  Public Safety
# street light repair  -->  Road & Infrastructure
# business tax application penalties  -->  Licensing & Permits
# pedestrian crosswalks signs  -->  Road & Infrastructure
# city of atlanta demolition lien foreclosure program  -->  Code Enforcement
# contractor cut inspection  -->  Road & Infrastructure
# city of atlanta emergency shelter referrals  -->  Public Safety
# missed trash collection  -->  Waste Management
# designated handicap parking  -->  Road & Infrastructure
# solid waste services - labor day collections  -->  Waste Management
# estreet missed recycling  -->  Waste Management
# estreet missed yard trimming  -->  Waste Management
# office of buildings - light commercial permits (construction)  -->  Licensing & Permits
# applying for atlanta police department's license and permits  -->  Licensing & Permits
# impound by fulton county police department  -->  Code Enforcement
# multiple business locations  -->  Licensing & Permits
# erosion control performance bond release for completed construction project  -->  Code Enforcement
# how to report drug activity  -->  Public Safety
# mayor's office of communications  -->  Public Safety
# how to request an adjustment to your water and sewer bill  -->  Water & Sewer
# information about storm water runoff and stormwater management  -->  Water & Sewer
# how to hire an off-duty atlanta police officer for an event  -->  Public Safety
# reinstall crosswalk sign  -->  Road & Infrastructure
# handicap parking space  -->  Waste Management
# public art, margaret mitchell square, monuments, murals, public art collection  -->  Road & Infrastructure
# invoicecloud department of watershed management (dwm) paperless sweepstakes  -->  Water & Sewer
# city of atlanta short term rental program  -->  Licensing & Permits
# request an officer be dispatched to perform a safety/welfare check on an atlanta resident  -->  Public Safety
# water and sewer account for online viewing and/or payment  -->  Water & Sewer
# request business tax refund equal to or less than five thousand dollars ($5000) from city of atlanta  -->  Licensing & Permits
# broken meter  -->  Water & Sewer
# ensuring compliance with land disturbance stop work order  -->  Code Enforcement
# non emergency sign repair  -->  Public Safety
# fire station locations  -->  Public Safety
# housing navigation intown referrals  -->  Code Enforcement
# feet on the street recycling campaign  -->  Waste Management
# service complaint - department of parks and recreation (dpr)  -->  Code Enforcement
# policing alternatives & diversion initiative pad - general information or media request  -->  Public Safety
# contact information for other police departments within city of atlanta's jurisdiction  -->  Public Safety
# recyclable items  -->  Waste Management
# graffiti on signs  -->  Code Enforcement
# meter investigation  -->  Water & Sewer
# requirements for obtaining fingerprinting at the atlanta police department  -->  Licensing & Permits
# report trash, debris, or other issues on georgia interstates and highways  -->  Code Enforcement
# what is a sewer cleanout and where do i find it?  -->  Waste Management
# missing persons - reporting  -->  Public Safety
# designated landmark, historic or conservation districts, buildings or sites  -->  Code Enforcement
# alleys in the city of atlanta  -->  Road & Infrastructure
# request payment for purchase order from city of atlanta  -->  Administrative / Account Services
# how to retrieve an impounded vehicle from the  atlanta police department  -->  Code Enforcement
# outdoor burning  -->  Public Safety
# general service complaint / compliment  -->  Public Safety
# meter investigations  -->  Water & Sewer
# establish service  -->  Licensing & Permits
# disconnect service  -->  Administrative / Account Services
# questions about refund request  -->  Administrative / Account Services
# missing or misapplied payment  -->  Administrative / Account Services
# balance inquiry  -->  Administrative / Account Services
# grease management  -->  Waste Management
# missing payment on a water and sewer accoun  -->  Water & Sewer
# voter registration and information in the state of georgia  -->  Licensing & Permits
# questions about adjustment  -->  Water & Sewer
# payment arrangement  -->  Administrative / Account Services
# parking lot configuration and landscape requirements  -->  Waste Management
# application requirements for the city of atlanta public right of way cart & kiosk vending program  -->  Licensing & Permits
# livestock / farm animals on residential & commercial property  -->  Code Enforcement
# reporting illegal removal or destruction of public property trees  -->  Code Enforcement
# credit refund request  -->  Administrative / Account Services
# process for picking up, changing and/or paying for a city of atlanta police report  -->  Administrative / Account Services
# why does the city of atlanta research easements on my property when handling my sewer problems?  -->  Road & Infrastructure
# reopening of city of atlanta facilities  -->  Licensing & Permits
# handicap parking space paint refresh  -->  Road & Infrastructure
# no parking sign  -->  Code Enforcement
# pavement marking for no parking  -->  Road & Infrastructure
# information on how to file a dispute  -->  Code Enforcement
# outdoor special event criteria  -->  Public Safety
# non-emergency sign repair, replacement, or installation  -->  Public Safety
# information on vehicles towed by the atlanta police department  -->  Code Enforcement
# will i have to pay to have my water service reconnected if it is cut off due to non-payment?  -->  Water & Sewer
# commercial fire inspections and permits  -->  Licensing & Permits
# contact city of atlanta ethics office  -->  Public Safety
# general inquiry  -->  Administrative / Account Services
# insufficient funds for business taxes  -->  Licensing & Permits
# i lost my citation  -->  Public Safety
# how to find out if there is a warrant out for your arrest  -->  Public Safety
# solid waste services - thanksgiving 2021 holiday collection schedule  -->  Waste Management
# replacement garbage bin  -->  Waste Management
# traffic signal timing inspection and adjustments  -->  Licensing & Permits
# vacant property amendment  -->  Code Enforcement
# missed backyard recycling  -->  Waste Management
# pothole repair needed  -->  Road & Infrastructure
# cost of permit for sewer connection  -->  Water & Sewer
# municipal court of atlanta refund policy  -->  Code Enforcement
# playground repairs in coa parks  -->  Road & Infrastructure
# application/renewal requirements for private property food and merchandise (combo) vending permit  -->  Licensing & Permits
# trash bin replacement  -->  Waste Management
# replacement recycle bin  -->  Waste Management
# customer report a burst pipe turn off water  -->  Water & Sewer
# solid waste services - christmas and new year collection schedule 2021  -->  Waste Management
# quality of life referral for oom constituent services - during pad holiday closure  -->  Public Safety
# pedestrian safety and planning in the city of atlanta  -->  Public Safety
# report a missing or damaged water meter lid  -->  Water & Sewer
# damaged garbage cart repair or replacement  -->  Waste Management
# atlcore - update email address or forgotten password assistance for business license  -->  Licensing & Permits
# christmas tree recycling  -->  Waste Management
# atlanta fire rescue department home surveys (fire safety checks)  -->  Public Safety
# estreet - street recycling  -->  Waste Management
# damaged recycling cart replacement  -->  Waste Management
# code enforcement - rodent/pest infestation  -->  Code Enforcement
# damaged garbage cart replacement  -->  Waste Management
# atlcore - merge accounts request  -->  Administrative / Account Services
# missing recycling cart  -->  Waste Management
# service complaint / compliment - department of public works (dpw)  -->  Code Enforcement
# atlcore - business license invoice not received  -->  Licensing & Permits
# department of watershed management (dwm) case status inquiry  -->  Public Safety
# missing garbage cart  -->  Waste Management
# e911 - public indecency pad referral  -->  Public Safety
# who is responsible for maintaining creeks in the city of atlanta?  -->  Water & Sewer
# code enforcement - interior water leak or flooding  -->  Water & Sewer
# code enforcement - open and vacant  -->  Code Enforcement
# quality-of-life concern  -->  Public Safety
# atlcore - hold on business license account  -->  Licensing & Permits
# contact atl311  -->  Public Safety
# code enforcement - interior structural damage  -->  Code Enforcement
# request new or cancel trash and recycling service  -->  Waste Management
# damaged, faded, or missing street name sign in need of replacement or repair  -->  Road & Infrastructure
# additional carts  -->  Waste Management
# report a missing or damaged water meter lid  - small meter  -->  Water & Sewer
# court procedures for code enforcement  -->  Code Enforcement
# non-profit business license renewal  -->  Licensing & Permits
# code enforcement - junk vehicle violation (private property)  -->  Code Enforcement
# missed scheduled bulk collection  -->  Code Enforcement
# code enforcement - unsafe structures  -->  Public Safety
# code enforcement inspection- interior water leak or flooding  -->  Water & Sewer
# business license zoning compliance  -->  Licensing & Permits
# non-emergency traffic signal repair  -->  Road & Infrastructure
# code enforcement - raw sewage  -->  Code Enforcement
# request for solid waste fee senior citizen discount  -->  Waste Management
# service complaint / compliment - department of transportation (atldot)  -->  Public Safety
# request for sidewalk repair  -->  Road & Infrastructure
# code enforcement - no heat  -->  Public Safety
# 2022 solid waste services holiday collection schedule  -->  Waste Management
# service complaint / compliment - department of watershed management (dwm)  -->  Water & Sewer
# service complaint / compliment - department of finance  -->  Code Enforcement
# dispute tree removal in public right of way  -->  Code Enforcement
# make an appointment to meet the mayor and/or contact the mayor's office  -->  Public Safety
# service complaint / compliment - atlanta police department - code enforcement (apd)  -->  Public Safety
# sewer tap location  -->  Water & Sewer
# code  enforcement - exposed wiring - outlet not working  -->  Public Safety
# save and e-verify affidavits  -->  Administrative / Account Services
# report loose metal plate- atlanta department of transportation  -->  Code Enforcement
# open records request for the department of transportation  -->  Code Enforcement
# bulk collection attempt  -->  Waste Management
# atlanta volunteer lawyers foundation - standing with survivors  -->  Public Safety
# request to unlock small meter  -->  Water & Sewer
# animal noise ordinance  -->  Code Enforcement
# site plan review - construction projects impacting the right of way trees  -->  Road & Infrastructure
# construction working hours  -->  Public Safety
# information about building materials, construction and demolition waste  -->  Waste Management
# atlcore - alcohol license invoice not received  -->  Licensing & Permits
# contact information and location of the public safety headquarters, police and fire rescue dept  -->  Public Safety
# shareable dockless mobility device permit request  -->  Licensing & Permits
# verify address is serviced by the city of atlanta  -->  Licensing & Permits
# how to verify a permit for a film production in your neighborhood  -->  Licensing & Permits
# sewer complaint in city of atlanta park  -->  Water & Sewer
# special administrative permit (sap) -  zoning districts  -->  Licensing & Permits
# solid waste services holiday collection schedule  -->  Waste Management
# code enforcement process  -->  Code Enforcement
# payment at parking meters for persons with disabilities  -->  Water & Sewer
# code enforcement - exposed wiring/outlet not working  -->  Public Safety
# property owner or renter request to establish new water and sewer services acct  -->  Water & Sewer
# report lost or stolen gun  -->  Code Enforcement
# illegal parking in the city of atlanta  -->  Code Enforcement
# request to withdraw new business license application in the city of atlanta  -->  Licensing & Permits
# left off water running (lowr)  -->  Water & Sewer
# traffic control permit full street closure  -->  Road & Infrastructure
# fire hydrant inspection  -->  Public Safety
# georgia department of community affairs rental assistance program  -->  Licensing & Permits
# what is my solid waste collection day?  -->  Waste Management
# find the owner of a property  -->  Code Enforcement
# city of atlanta fire code  -->  Public Safety
# what is the waste wizard solid waste services collection tool?  -->  Waste Management
# peer2peer warm line - ga mental health consumer network non-emergency behavioral health support  -->  Public Safety
# atlanta habitat for humanity home repair services  -->  Waste Management
# film and entertainment 411 directory staff  -->  Public Safety
# film and entertainment permits  -->  Licensing & Permits
# black ice on road and other dangerous snow and ice related conditions on roadway  -->  Road & Infrastructure
# metropolitan atlanta rapid transit authority (marta)  -->  Licensing & Permits
# covid-19 emergency rental assistance program through united way  -->  Public Safety
# fusus - connect atlanta  -->  Public Safety
# how to request adjustment of streetlight brightness  -->  Road & Infrastructure
# tyler perry's donation to prevent displacement of atlanta's legacy residents  -->  Road & Infrastructure
# cad drawings, floor plans, as build drawings  -->  Waste Management
# unpaid property tax and solid waste liens with fulton or dekalb county  -->  Code Enforcement
# donation of real estate to the city  -->  Code Enforcement
# google fiber construction inquiries  -->  Road & Infrastructure
# traffic study inspection  -->  Road & Infrastructure
# transfer to apd/ems - quality of life concern  -->  Public Safety
# grass cutting in quadrant  -->  Waste Management
# booted car  -->  Public Safety
# atlanta department of transportation "light up the night" initiative  -->  Public Safety
# how to request a new bicycle lane or path  -->  Road & Infrastructure
# capital projects under construction  -->  Road & Infrastructure
# neighborhood crime statistics  -->  Code Enforcement
# code enforcement civil process  -->  Code Enforcement
# lost & found- lost items while on city property  -->  Code Enforcement
# backyard service re-certification process  -->  Licensing & Permits
# code enforcement - inoperable kitchen appliance  -->  Code Enforcement
# atl plus inquiries  -->  Administrative / Account Services
# city of atlanta department of enterprise assets management  -->  Licensing & Permits
# service complaint / compliment - department of parks and recreation (dpr)  -->  Code Enforcement
# how to void a code enforcement case created in error  -->  Code Enforcement
# how to request a cash bond refund from municipal court  -->  Code Enforcement
# sws hydraulic fluid leaking on the street  -->  Water & Sewer
# domestic partnership  -->  Administrative / Account Services
# report cybercrime  -->  Code Enforcement
# code enforcement - parking on grass/non-all weather surface  -->  Code Enforcement
# extension/relocation/cutting and plugging of water mains  -->  Water & Sewer
# in-rem review board hearing  -->  Public Safety
# woodchips from tree/stump removal  -->  Waste Management
# file a discrimination complaint with the human relations commission  -->  Public Safety
# request a police officer direct traffic due to traffic signal not working  -->  Public Safety
# curbside inquiries  -->  Road & Infrastructure
# housing navigation project or services referrals  -->  Code Enforcement
# request a crime prevention or neighborhood/business watch meeting with mcgruff (crime dog)  -->  Public Safety
# service compliment - department of public works (dpw)  -->  Administrative / Account Services
# request a car seat  -->  Public Safety
# report information regarding a crime to crime stoppers  -->  Public Safety
# senior ball 2023: an evening to remember  -->  Licensing & Permits
# horticulture in coa parks and greenspaces  -->  Waste Management
# backflow prevention for meter purchases (fire services, commercial, domestic and irrigation)  -->  Water & Sewer
# septic tank and porta potty waste disposal  -->  Waste Management
# code enforcement - no air conditioning (ac)  -->  Public Safety
# city of atlanta greenway property  -->  Road & Infrastructure
# how to expedite a film and entertainment permit  -->  Licensing & Permits
# permit for sign erection  -->  Licensing & Permits
# code enforcement - overgrowth  -->  Code Enforcement
# tree removal - public property  -->  Code Enforcement
# boil water advisory  -->  Water & Sewer
# request atl311 participation at a community event or meeting  -->  Public Safety
# horticulture- flower beds and maintenance  -->  Waste Management
# atlanta-fulton county emergency management agency  -->  Public Safety
# restaurant closure after alcohol serving hours end  -->  Licensing & Permits
# fulton county department of behavioral health & developmental disabilities  -->  Public Safety
# service complaint / compliment - apd - code enforcement  -->  Code Enforcement
# coa park or recreation reservations  -->  Licensing & Permits
# cart pick up  -->  Waste Management
# garbage or recycling cart not properly placed back at curb after collection  -->  Waste Management
# marta stop or city of atlanta community garbage bin that needs to be serviced  -->  Waste Management
# domestic partnership - qualification assessment  -->  Administrative / Account Services
# vacant property removal  -->  Code Enforcement
# how do i dispute a parking ticket?  -->  Code Enforcement
# in rem process  -->  Licensing & Permits
# atlanta homeless continuum of care  -->  Public Safety
# adopt a spot/street program (department of public works)  -->  Road & Infrastructure
# pfh lift 2.0  -->  Waste Management
# bridge or guard rail repairs  -->  Road & Infrastructure
# code enforcement - parking on grass/ non-all weather surface  -->  Code Enforcement
# new parking meter request  -->  Water & Sewer
# vacant property outside of city limits  -->  Code Enforcement
# in rem review board hearing  -->  Public Safety
# illegal dumping  -->  Code Enforcement
# afrd request for additional cart(s) at a fire station  -->  Public Safety
# shareable dockless mobility device geofence request inquiry  -->  Road & Infrastructure
# report a vehicle as stolen  -->  Code Enforcement
# how to request other pavement markings  -->  Road & Infrastructure
# office of revenue - lien payoff requests  -->  Administrative / Account Services
# report a leaking or broken water meter  -->  Water & Sewer
# how to report a hit and run accident  -->  Public Safety
# grady mobile crisis response team  -->  Public Safety
# delete/remove a department of watershed online portal account  -->  Administrative / Account Services
# car seat installation by the atlanta fire rescue department (afrd)  -->  Public Safety
# family diversion problem-solving strategy and housing solutions  -->  Waste Management
# service complaint / compliment - atlanta police department (non-code enforcement)  -->  Public Safety
# commercial parking permits  -->  Licensing & Permits
# city of atlanta map requests  -->  Road & Infrastructure
# e-911 panhandling pad referral  -->  Public Safety
# how to report a production that is filming beyond the permitted time  -->  Public Safety
# contaminated recycling cart  -->  Waste Management
# how can i do business with the city of atlanta?  -->  Licensing & Permits
# commercial buildings fire alarm system review  -->  Public Safety
# code enforcement - vacant property registration process  -->  Code Enforcement
# days for retrieving personal property held by apd due to arrest, lost/found, evidence, or theft  -->  Code Enforcement
# code enforcement - compliance resolution  -->  Public Safety
# someone i know with a mental illness or developmental disability, was recently detained in atlanta.  -->  Public Safety
# bicycle rack and bicycle mural requests/installation  -->  Waste Management
# housing help center  -->  Public Safety
# information about winter warming centers & resources in city of atlanta  -->  Public Safety
# shared-use mobility devices (scooters, bicycles, and e-bikes)  -->  Waste Management
# diversion problem-solving strategy and housing solution referral  -->  Public Safety
# code enforcement - vacant property amendment  -->  Code Enforcement
# housing navigation project or services referral  -->  Code Enforcement
# housing help center assistance request  -->  Public Safety
# how do i change my address with the municipal court of atlanta?  -->  Licensing & Permits
# housing help center follow up request  -->  Public Safety
# code enforcement - demolition process  -->  Code Enforcement
# adopt a spot/street program  -->  Road & Infrastructure
# request copy of business tax certificate  -->  Licensing & Permits
# fire department headquarters  -->  Public Safety
# city of atlanta section 8 program - unit repairs  -->  Road & Infrastructure
# open records request for the city of atlanta office of constituent services  -->  Administrative / Account Services
# open records request for the city of atlanta department of finance  -->  Administrative / Account Services
# someone i know with a mental illness or developmental disability, was recently detained in atl (pad)  -->  Public Safety
# star-c eviction prevention program  -->  Code Enforcement
# business tax citation issued  -->  Licensing & Permits
# the salvation army programs and services  -->  Waste Management
# continuum of care access points - outside city of atlanta  -->  Public Safety
# check the status of a police case  -->  Public Safety
# tips about frozen water pipes  -->  Water & Sewer
# snow and ice level of readiness and response based on forecasted weather  -->  Road & Infrastructure
# open records request for the city of atlanta department of law  -->  Code Enforcement
# cancel or modify sws collection day reminder  -->  Waste Management
# banner permits  -->  Licensing & Permits
# what are the code enforcement warning signs on a property?  -->  Code Enforcement
# park visioning, master planning and park adoption  -->  Licensing & Permits
# exposed wiring - outlet not working  -->  Road & Infrastructure
# housing solution services  -->  Waste Management
# gateway eviction prevention  -->  Public Safety
# register an alarm system  -->  Public Safety
# how do i pay a school bus violation ticket?  -->  Code Enforcement
# report aggressive/vicious dogs or other animals  -->  Code Enforcement
# fulton county state, superior and magistrate court  -->  Licensing & Permits
# accident reports in the city of atlanta  -->  Public Safety
# management of city-owned real estate  -->  Code Enforcement
# reporting underpass bridge encampments  -->  Water & Sewer
# markings for preferential lanes  -->  Waste Management
# atlanta city hall tour request  -->  Licensing & Permits
# open records request for the department of city planning  -->  Code Enforcement
# how to contact the city of atlanta mayor's office of film and entertainment  -->  Code Enforcement
# code  enforcement - exposed wiring/outlet not working  -->  Public Safety
# address not on garbage/recycling cart  -->  Waste Management
# community clean up with keep atlanta beautiful commission  -->  Waste Management
# information about the plumbing repair assistance program via care and conserve  -->  Water & Sewer
# atlanta beltline  -->  Waste Management
# zoning verification letter  -->  Licensing & Permits
# special operations/city council inquiries  -->  Public Safety
# real estate for sale by the city  -->  Code Enforcement
# service complaint / compliment - municipal court (mun)  -->  Code Enforcement
# amplified sounds in coa parks  -->  Waste Management
# city of atlanta greenspace property  -->  Code Enforcement
# city of atlanta park rules and enforcement  -->  Code Enforcement
# camp best friends summer program  -->  Public Safety
# driver's license  -->  Licensing & Permits
# housing & utility assistance opportunities through aid atlanta  -->  Licensing & Permits
# the mayor's office of equity, diversity and inclusion  -->  Waste Management
# request for additional cart(s) at a city of atlanta facility  -->  Waste Management
# residential permit for overnight guests to park on permitted street  -->  Licensing & Permits
# cleanliness of sidewalks  -->  Road & Infrastructure
# cardboard containers and similar articles  -->  Waste Management
# dwm sewer system smoke testing  -->  Water & Sewer
# city of atlanta small business water service disruption recovery fund  -->  Water & Sewer
# theft - personal property  -->  Code Enforcement
# how is the atlanta beltline handling public safety?  -->  Public Safety
# senior ball 2024  -->  Licensing & Permits
# speed tables  -->  Waste Management
# report reckless driving of an employee while in a city issued vehicle (non- apd)  -->  Public Safety
# senior ball 2024: putting on the glitz  -->  Waste Management
# customer inquiry on refund check received from the city of atlanta  -->  Administrative / Account Services
# information about the more marta program  -->  Licensing & Permits
# atlanta fire rescue smoke alarm program  -->  Public Safety
# can i retrieve an item mistakenly discarded in garbage collected by dpw?  -->  Code Enforcement
# property setback ordinances (front and side/rear/transitional yards)  -->  Code Enforcement
# truck and freight routes within the city of atlanta  -->  Waste Management
# coa park/beltline maintenance and facility repair  -->  Waste Management
# residential parking permit- lost, stolen or new vehicle  -->  Licensing & Permits
# metro atlanta county courthouse locations  -->  Licensing & Permits
# senior citizen anti-displacement grant  -->  Road & Infrastructure
# hopwa central intake - permanent housing placement  -->  Water & Sewer
# code enforcement - clean and close process  -->  Administrative / Account Services
# hopwa central intake - tenant based rental assistance  -->  Water & Sewer
# business license account review and/or audit  -->  Licensing & Permits
# process for subdividing property  -->  Code Enforcement
# court correction  -->  Public Safety
# hopwa central intake - short term rent mortgage and utility assistance  -->  Water & Sewer
# scheduling a final site inspection for land disturbance projects  -->  Code Enforcement
# blight tax for absentee property owners  -->  Code Enforcement
# fire service hydraulic tests (requirements for flow test and 24 hour test)  -->  Water & Sewer
# release of inmate property  -->  Code Enforcement
# what is the location and hours of the municipal court of atlanta?  -->  Licensing & Permits
# requirements for obtaining a background check/criminal history/arrest record at atlanta police  -->  Licensing & Permits
# public works vehicle leaking fluid on the street  -->  Road & Infrastructure
# biolab fire - air quality monitoring in atlanta  -->  Public Safety
# attorney requests to speak with the case manager  -->  Public Safety
# hopwa central intake - facility based housing  -->  Waste Management
# revenue compliance appointment request  -->  Administrative / Account Services
# code enforcement - vacant property removal  -->  Code Enforcement
# report a fallen traffic camera  -->  Road & Infrastructure
# public works vehicle leaking hydraulic fluid on the street  -->  Road & Infrastructure
# atl311 mail/fax request  -->  Administrative / Account Services
# feeding the homeless community in the city of atlanta  -->  Road & Infrastructure
# clearance letter  -->  Administrative / Account Services
# how to dispose of hazardous household materials  -->  Waste Management
# application/renewal requirements for the city of atlanta private property service vending permit  -->  Licensing & Permits
# atlcore - update email address/forgotten password assistance for occupation tax /business account  -->  Administrative / Account Services
# atlcore – update email address or forgotten password assistance for business license  -->  Licensing & Permits
# department of watershed managment account adjustment form  -->  Water & Sewer
# atlcore – alcohol license invoice not received  -->  Licensing & Permits
# atlcore – update email address/forgotten password assistance for business occupation tax account  -->  Administrative / Account Services
# report a missing or damaged water meter lid – small meter  -->  Water & Sewer
# service complaint / compliment – department of transportation (atldot)  -->  Public Safety
# missed trash pickup  -->  Waste Management
# office of buildings – arborist division  -->  Road & Infrastructure
# hopwa central intake – short term rent mortgage and utility assistance  -->  Water & Sewer
# hopwa central intake – tenant based rental assistance  -->  Water & Sewer
# request copy of business occupation tax certificate  -->  Licensing & Permits
# damaged traffic/surveillance camera  -->  Road & Infrastructure
# marta stop or city of atlanta community garbage binthat needs to be serviced  -->  Waste Management
# atlcore – hold on business occupation tax account  -->  Administrative / Account Services
# atlcore – merge accounts request  -->  Administrative / Account Services
# atlcore – business occupation tax invoice not received  -->  Administrative / Account Services
# office of buildings – inspections  -->  Public Safety
# request to withdraw new business occupation tax application in the city of atlanta  -->  Licensing & Permits

# %%
df.to_csv("../data/geocoded_data/merged_data_with_categories2.csv", index=False)

# %%
category_scores = {
    "Public Safety": 10,                       # emergency, danger
    "Water & Sewer": 9,                        # flooding, sanitation risk
    "Road & Infrastructure": 8,                # traffic, physical risk
    "Waste Management": 7,                     # hygiene impact
    "Code Enforcement": 6,                     # compliance issues
    "Licensing & Permits": 5,                  # business impact
    "Administrative / Account Services": 4,    # billing/info
    "Other": 3                                 # uncategorized
}

# %%
df["category_score"] = df["category"].map(category_scores)

# %%
print(df["category_score"].isna().sum())
# Out:
# 0

# %%
max_score = max(category_scores.values())

df["category_score_norm"] = df["category_score"] / max_score

# %%
df.to_csv("../data/geocoded_data/merged_data_with_categories_score.csv", index=False)

# %%
df.columns
# Out:
# Index(['Opened', 'Description', 'Address', 'Zip Code', 'Closed Date 1',
#        'Closed Date 2', 'Status', 'Number', 'closed', 'resolution_time_hours',
#        'has_closure_time', 'zip_clean', 'zip_int', 'address_norm', 'lat',
#        'lng', 'ok', 'year', 'Short Description', 'Description_norm',
#        'category', 'category_score', 'category_score_norm'],
#       dtype='object')
